# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../'))

import techind as ti
import pandas as pd

df = pd.read_pickle('../data/test_data01.pkl')

df['WMA'] = ti.weightedMovingAverage(30, df['adjclose'].values)

df.tail()
# Out:
#             adjclose       WMA
# date
# 2019-12-24      0.55  0.508151
# 2019-12-26      0.62  0.515763
# 2019-12-27      0.57  0.519785
# 2019-12-30      0.57  0.523656
# 2019-12-31      0.59  0.528710

# %%
df.loc[df.index > pd.to_datetime("2018-01-01").date()].plot(figsize=(16,10))
# Out:
# <Axes: xlabel='date'>
